# %%
import pandas as pd

# %%
gyo = pd.read_csv('C:/Users/Shin/Desktop/for_kr_pjt/교량_data.csv', encoding='CP949')
# Out:
# C:\Users\Shin\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (28) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
gyo.tail(10)
# Out:
#                 교량명    도로노선명    시도명 시군구명  시군구코드            소재지지번주소    교량시작점위도  \
# 35180         주상천2교       군도   전라북도  부안군  45800       전라북도 부안군 하서면   0.000000
# 35181           지경교       시도   전라북도  군산시  45130       전라북도 군산시 대야면   0.000000
# 35182           운산교       군도   전라북도  부안군  45800   전라북도 부안군 동진면 안성리  35.785551
# 35183         인천신항교       기타  인천광역시  연수구  28185      인천광역시 연수구 송도동  37.348628
# 35184          아암1교  특별,광역시도  인천광역시  연수구  28185      인천광역시 연수구 송도동  37.419259
# 35185          아암2교  특별,광역시도  인천광역시  연수구  28185      인천광역시 연수구 송도동  37.429930
# 35186          아암3교  특별,광역시도  인천광역시   중구  28110     인천광역시 중구 신흥동3가  37.431460
# 35187           연도교       기타  인천광역시  옹진군  28720  인천광역시 옹진군 연평면 연평리  37.655434
# 35188   연평도항 북측 연도교       군도  인천광역시  옹진군  28720  인천광역시 옹진군 연평면 연평리   0.000000
# 35189  헬기이착륙패드 연결교량       기타    강원도  원주시  42130    강원도 원주시 지정면 판대리  37.410666
#
#           교량시작점경도    교량종료점위도     교량종료점경도  교량높이
# 35180    0.000000   0.000000    0.000000   5.0
# ...

# %%
print(gyo.columns)
# Out:
# Index(['교량명', '시설물종별등급구분', '도로종류', '도로노선명', '도로노선번호', '도로노선방향', '시도명', '시군구명',
#        '시군구코드', '소재지도로명주소', '소재지지번주소', '교량시작점위도', '교량시작점경도', '교량종료점위도',
#        '교량종료점경도', '교량연장', '교량폭', '교량보도폭', '교량높이', '차로수', '상하행선분리여부', '상부구조형식',
#        '교량준공년도', '최종안전점검일자', '최종안전점검결과', '최종안전점검유형', '내진설계적용여부', '내진성능확보여부',
#        '교량보수보강내역', '교량보수보강비용', '설계활하중', '허용통행하중', '하부통과제한높이', '관리기관명',
#        '관리기관전화번호', '데이터기준일자'],
#       dtype='object')

# %%
gyo = gyo.drop(['시설물종별등급구분', '도로종류', '도로노선번호', '도로노선방향','소재지도로명주소', '교량연장', '교량폭', '교량보도폭',
          '차로수', '상하행선분리여부', '상부구조형식', '교량준공년도', '최종안전점검일자', '최종안전점검결과', '최종안전점검유형',
          '내진설계적용여부', '내진성능확보여부', '교량보수보강내역', '교량보수보강비용', '설계활하중', '허용통행하중',
          '하부통과제한높이', '관리기관명', '관리기관전화번호', '데이터기준일자'], axis=1)

# %%
gyo
# Out:
#                 교량명     도로노선명    시도명 시군구명  시군구코드            소재지지번주소  \
# 0               진위교   일반국도1호선    경기도  평택시  41220    경기도 평택시 진위면 견산리
# 1               풍계교   일반국도3호선    경기도  이천시  41500   경기도 이천시 장호원읍 선읍리
# 2               태평교   일반국도3호선    경기도  여주시  41670    경기도 여주시 가남읍 태평리
# 3               장평교   일반국도3호선    경기도  이천시  41500    경기도 이천시 대월면 장평리
# 4               풍계교  일반국도37호선    경기도  이천시  41500   경기도 이천시 장호원읍 풍계리
# ...             ...       ...    ...  ...    ...                ...
# 35185          아암2교   특별,광역시도  인천광역시  연수구  28185      인천광역시 연수구 송도동
# 35186          아암3교   특별,광역시도  인천광역시   중구  28110     인천광역시 중구 신흥동3가
# 35187           연도교        기타  인천광역시  옹진군  28720  인천광역시 옹진군 연평면 연평리
# 35188   연평도항 북측 연도교        군도  인천광역시  옹진군  28720  인천광역시 옹진군 연평면 연평리
# 35189  헬기이착륙패드 연결교량        기타    강원도  원주시  42130    강원도 원주시 지정면 판대리
#
#          교량시작점위도     교량시작점경도    교량종료점위도     교량종료점경도  교량높이
# 0      37.100899  127.064133  37.101935  127.063864   4.6
# ...

# %%
sido_groupby = gyo.groupby(["시도명"])

# %%
sido_groupby.size()
# Out:
# 시도명
# 강원도        4017
# 경기도        5946
# 경상남도       3789
# 경상북도       5210
# 광주광역시       399
# 대구광역시       599
# 대전광역시       487
# 부산광역시       606
# 서울특별시       483
# 세종특별자치시     199
# 울산광역시       645
# 인천광역시       438
# 전라남도       3228
# 전라북도       2826
# 제주특별자치도     463
# 충청남도       3056
# 충청북도       2799
# dtype: int64

# %%
df1 = gyo.loc[gyo["시도명"]=="경기도"]

# %%
df2 = gyo.loc[gyo["시도명"]=="서울특별시"]

# %%
df3 = gyo.loc[gyo["시도명"]=="인천광역시"]

# %%
gyoryang = pd.concat([df1, df2, df3])

# %%
gyoryang
# Out:
#                교량명     도로노선명    시도명 시군구명  시군구코드            소재지지번주소    교량시작점위도  \
# 0              진위교   일반국도1호선    경기도  평택시  41220    경기도 평택시 진위면 견산리  37.100899
# 1              풍계교   일반국도3호선    경기도  이천시  41500   경기도 이천시 장호원읍 선읍리  37.133443
# 2              태평교   일반국도3호선    경기도  여주시  41670    경기도 여주시 가남읍 태평리  37.200325
# 3              장평교   일반국도3호선    경기도  이천시  41500    경기도 이천시 대월면 장평리  37.225055
# 4              풍계교  일반국도37호선    경기도  이천시  41500   경기도 이천시 장호원읍 풍계리  37.149231
# ...            ...       ...    ...  ...    ...                ...        ...
# 35184         아암1교   특별,광역시도  인천광역시  연수구  28185      인천광역시 연수구 송도동  37.419259
# 35185         아암2교   특별,광역시도  인천광역시  연수구  28185      인천광역시 연수구 송도동  37.429930
# 35186         아암3교   특별,광역시도  인천광역시   중구  28110     인천광역시 중구 신흥동3가  37.431460
# 35187          연도교        기타  인천광역시  옹진군  28720  인천광역시 옹진군 연평면 연평리  37.655434
# 35188  연평도항 북측 연도교        군도  인천광역시  옹진군  28720  인천광역시 옹진군 연평면 연평리   0.000000
#
# ...

# %%
gyoryang.to_csv("교량_data.csv", encoding='CP949')

# %%
test = pd.read_csv("교량_data.csv", encoding='CP949')

# %%
test
# Out:
#               교량명     도로노선명    시도명 시군구명  시군구코드            소재지지번주소    교량시작점위도  \
# 0             진위교   일반국도1호선    경기도  평택시  41220    경기도 평택시 진위면 견산리  37.100899
# 1             풍계교   일반국도3호선    경기도  이천시  41500   경기도 이천시 장호원읍 선읍리  37.133443
# 2             태평교   일반국도3호선    경기도  여주시  41670    경기도 여주시 가남읍 태평리  37.200325
# 3             장평교   일반국도3호선    경기도  이천시  41500    경기도 이천시 대월면 장평리  37.225055
# 4             풍계교  일반국도37호선    경기도  이천시  41500   경기도 이천시 장호원읍 풍계리  37.149231
# ...           ...       ...    ...  ...    ...                ...        ...
# 6862         아암1교   특별,광역시도  인천광역시  연수구  28185      인천광역시 연수구 송도동  37.419259
# 6863         아암2교   특별,광역시도  인천광역시  연수구  28185      인천광역시 연수구 송도동  37.429930
# 6864         아암3교   특별,광역시도  인천광역시   중구  28110     인천광역시 중구 신흥동3가  37.431460
# 6865          연도교        기타  인천광역시  옹진군  28720  인천광역시 옹진군 연평면 연평리  37.655434
# 6866  연평도항 북측 연도교        군도  인천광역시  옹진군  28720  인천광역시 옹진군 연평면 연평리   0.000000
#
# ...
