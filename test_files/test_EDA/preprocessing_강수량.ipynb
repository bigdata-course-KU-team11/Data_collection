# %%
import pandas as pd
from datetime import datetime

# %%
df = pd.read_csv('C:\\jupyter_notebook_file\\NoonMap_origin\\NoonMap-Project\\data\\file_data\\강수량_api.csv')
df.head(10)
# Out:
#    Unnamed: 0  station_code    obs_date  rainfall
# 0           0      10064030  2010123123       0.0
# 1           1      10064030  2010123122       0.0
# 2           2      10064030  2010123121       0.0
# 3           3      10064030  2010123120       0.0
# 4           4      10064030  2010123119       0.0
# 5           5      10064030  2010123118       0.0
# 6           6      10064030  2010123117       0.0
# 7           7      10064030  2010123116       0.0
# 8           8      10064030  2010123115       0.0
# 9           9      10064030  2010123114       1.0

# %%
df.tail(5)
# Out:
#          Unnamed: 0  station_code    obs_date  rainfall
# 9829021     9829021      51014020  2020010203       0.0
# 9829022     9829022      51014020  2020010202       0.0
# 9829023     9829023      51014020  2020010201       0.0
# 9829024     9829024      51014020  2020010200       0.0
# 9829025     9829025      51014020  2020010123       0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9829026 entries, 0 to 9829025
# Data columns (total 4 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   Unnamed: 0    int64
#  1   station_code  int64
#  2   obs_date      datetime64[ns]
#  3   rainfall      float64
# dtypes: datetime64[ns](1), float64(1), int64(2)
# memory usage: 300.0 MB

# %%
df['obs_date'] = pd.to_datetime(df['obs_date'], format='%Y%m%d%H')

# %%
pd.unique(df['station_code']).tolist()
# Out:
# [10064030,
#  10074010,
#  10074020,
#  10074030,
#  10074040,
#  10074060,
#  10074070,
#  10074080,
#  10074090,
#  10074100,
#  10074110,
#  10074120,
#  10074170,
#  10074175,
#  10134020,
#  10134030,
#  10134045,
#  10134140,
#  10154010,
#  10154020,
#  10154030,
#  10154032,
#  10154035,
#  10164010,
#  10164020,
#  10164030,
#  10164040,
#  10164050,
#  10164060,
#  10164070,
#  10164075,
#  10164080,
#  10174020,
#  10184010,
#  10184020,
#  10184030,
#  10184040,
#  10184050,
#  10184060,
#  10184070,
#  10184080,
#  10184090,
#  10184100,
#  10184110,
#  10184120,
#  10184125,
#  10184130,
#  10184140,
#  10184150,
#  10184160,
#  10184170,
#  10184180,
#  10184190,
#  10184200,
#  10184210,
#  10184220,
#  10184230,
#  10184232,
#  10194010,
#  10194020,
#  10194030,
#  10204010,
#  10204020,
#  10214010,
#  10214020,
#  10214030,
#  10224010,
#  10224020,
#  10224040,
#  10224050,
#  10224060,
#  10224070,
#  10224090,
#  10234010,
#  10234020,
#  10234030,
#  10234040,
#  11014010,
#  11014020,
#  11014030,
#  11014040,
#  11014060,
#  11014070,
#  11014080,
#  11014090,
#  11014100,
#  11014120,
#  11014130,
#  11014140,
#  12014010,
#  12024010,
#  12024020,
#  20024025,
#  20084060,
#  20124030,
#  20214140,
#  22014080,
#  30014020,
#  30014120,
#  33024020,
#  40044010,
#  51014020]

# %%
df_station = pd.read_csv('C:\\jupyter_notebook_file\\NoonMap_origin\\NoonMap-Project\\data\\file_data\\강수량관측소_좌표변환.csv')
df_station.head(10)
# Out:
#    Unnamed: 0  Unnamed: 0.1  station_code agency_name   station_name  \
# 0           0            87      10064030         환경부  양평군(양동주민자치센터)
# 1           1            97      10074010         환경부       양평군(양평교)
# 2           2            98      10074020         환경부            장호원
# 3           3            99      10074030         환경부      여주시(여주대교)
# 4           4           100      10074040         환경부    양평군(청운면사무소)
# 5           5           102      10074060         환경부     이천시(이천남초교)
# 6           6           103      10074070         환경부      여주시(금당초교)
# 7           7           104      10074080         환경부      안성시(삼죽초교)
# 8           8           105      10074090         환경부      이천시(장천초교)
# 9           9           106      10074100         환경부       여주시(주암리)
#
#         address             etc_address  longitude   latitude     tr_lat  \
# 0       경기도 양평군  양동면 학둔지아래길 24 양동주민자치센터  127-45-05  37-25-28   37.424444
# 1       경기도 양평군             양평읍 양근리 양평교  127-29-24  37-29-11   37.486389
# 2  경기도 이천군 장호원읍                창전리 읍사무소  127-37-00  37-01-00   37.016667
# 3       경기도 여주시           상동 여주대교 상류 좌안  127-38-53  37-17-43   37.295278
# 4       경기도 양평군      청운면 용두로 170 청운면사무소  127-42-38  37-33-23   37.556389
# 5       경기도 이천시  경충대로 2614번길 32 이천남초등학교  127-26-35  37-16-37   37.276944
# 6       경기도 여주시      가남읍 가남로 649 금당초등학교  127-36-20  37-11-51   37.197500
# 7       경기도 안성시     삼죽면 삼죽초교길 20 삼죽초등학교  127-22-28  37-04-36   37.076667
# 8       경기도 이천시   설성면 설성로 164-25 장천초등학교  127-31-39  37-08-45   37.145833
# 9       경기도 여주시    북내면 주암길225-3 (구)주암분교  127-40-46  37-23-50   37.397222
#
#       tr_long
# 0  127.751389
# 1  127.490000
# 2  127.616667
# 3  127.648056
# 4  127.710556
# 5  127.443056
# 6  127.605556
# 7  127.374444
# 8  127.527500
# 9  127.679444

# %%
sudo_station_list = pd.unique(df_station['station_code']).tolist()
sudo_station_list
# Out:
# [10064030,
#  10074010,
#  10074020,
#  10074030,
#  10074040,
#  10074060,
#  10074070,
#  10074080,
#  10074090,
#  10074100,
#  10074110,
#  10074120,
#  10074170,
#  10074175,
#  10134020,
#  10134030,
#  10134045,
#  10134140,
#  10154010,
#  10154020,
#  10154030,
#  10154032,
#  10154035,
#  10164010,
#  10164020,
#  10164030,
#  10164040,
#  10164050,
#  10164060,
#  10164070,
#  10164075,
#  10164080,
#  10174020,
#  10184010,
#  10184020,
#  10184030,
#  10184040,
#  10184050,
#  10184060,
#  10184070,
#  10184080,
#  10184090,
#  10184100,
#  10184110,
#  10184120,
#  10184125,
#  10184130,
#  10184140,
#  10184150,
#  10184160,
#  10184170,
#  10184180,
#  10184190,
#  10184200,
#  10184210,
#  10184220,
#  10184230,
#  10184232,
#  10194010,
#  10194020,
#  10194030,
#  10204010,
#  10204020,
#  10214010,
#  10214020,
#  10214030,
#  10224010,
#  10224020,
#  10224040,
#  10224050,
#  10224060,
#  10224070,
#  10224090,
#  10234010,
#  10234020,
#  10234030,
#  10234040,
#  11014010,
#  11014020,
#  11014030,
#  11014040,
#  11014060,
#  11014070,
#  11014080,
#  11014090,
#  11014100,
#  11014120,
#  11014130,
#  11014140,
#  12014010,
#  12024010,
#  12024020]

# %% [markdown]
# #### 강수량 관측소와 강수량 데이터 병합

# %%
merge_df = pd.merge(df_station, df, on='station_code')

# %%
merge_df
# Out:
#          Unnamed: 0_x  Unnamed: 0.1  station_code agency_name   station_name  \
# 0                   0            87      10064030         환경부  양평군(양동주민자치센터)
# 1                   0            87      10064030         환경부  양평군(양동주민자치센터)
# 2                   0            87      10064030         환경부  양평군(양동주민자치센터)
# 3                   0            87      10064030         환경부  양평군(양동주민자치센터)
# 4                   0            87      10064030         환경부  양평군(양동주민자치센터)
# ...               ...           ...           ...         ...            ...
# 8865391            91           246      12024020         환경부       안산시(장상동)
# 8865392            91           246      12024020         환경부       안산시(장상동)
# 8865393            91           246      12024020         환경부       안산시(장상동)
# 8865394            91           246      12024020         환경부       안산시(장상동)
# 8865395            91           246      12024020         환경부       안산시(장상동)
#
#          address             etc_address  longitude   latitude     tr_lat  \
# 0        경기도 양평군  양동면 학둔지아래길 24 양동주민자치센터  127-45-05  37-25-28   37.424444
# 1        경기도 양평군  양동면 학둔지아래길 24 양동주민자치센터  127-45-05  37-25-28   37.424444
# 2        경기도 양평군  양동면 학둔지아래길 24 양동주민자치센터  127-45-05  37-25-28   37.424444
# 3        경기도 양평군  양동면 학둔지아래길 24 양동주민자치센터  127-45-05  37-25-28   37.424444
# 4        경기도 양평군  양동면 학둔지아래길 24 양동주민자치센터  127-45-05  37-25-28   37.424444
# ...          ...                     ...        ...        ...        ...
# 8865391  경기도 안산시       상록구 장상동 523 (동막골)  126-52-51  37-21-03   37.350833
# 8865392  경기도 안산시       상록구 장상동 523 (동막골)  126-52-51  37-21-03   37.350833
# 8865393  경기도 안산시       상록구 장상동 523 (동막골)  126-52-51  37-21-03   37.350833
# 8865394  경기도 안산시       상록구 장상동 523 (동막골)  126-52-51  37-21-03   37.350833
# 8865395  경기도 안산시       상록구 장상동 523 (동막골)  126-52-51  37-21-03   37.350833
#
#             tr_long  Unnamed: 0_y            obs_date  rainfall
# 0        127.751389             0 2010-12-31 23:00:00       0.0
# 1        127.751389             1 2010-12-31 22:00:00       0.0
# 2        127.751389             2 2010-12-31 21:00:00       0.0
# 3        127.751389             3 2010-12-31 20:00:00       0.0
# 4        127.751389             4 2010-12-31 19:00:00       0.0
# ...             ...           ...                 ...       ...
# 8865391  126.880833       8865391 2020-01-02 03:00:00       0.0
# 8865392  126.880833       8865392 2020-01-02 02:00:00       0.0
# 8865393  126.880833       8865393 2020-01-02 01:00:00       0.0
# 8865394  126.880833       8865394 2020-01-02 00:00:00       0.0
# 8865395  126.880833       8865395 2020-01-01 23:00:00       0.0
#
# [8865396 rows x 14 columns]

# %%
merge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8865396 entries, 0 to 8865395
# Data columns (total 14 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   Unnamed: 0_x  int64
#  1   Unnamed: 0.1  int64
#  2   station_code  int64
#  3   agency_name   object
#  4   station_name  object
#  5   address       object
#  6   etc_address   object
#  7   longitude     object
#  8   latitude      object
#  9   tr_lat        float64
#  10  tr_long       float64
#  11  Unnamed: 0_y  int64
#  12  obs_date      datetime64[ns]
#  13  rainfall      float64
# dtypes: datetime64[ns](1), float64(3), int64(4), object(6)
# memory usage: 1014.6+ MB

# %%
# 관측소 갯수, 관측소별 데이터 갯수
total = 0
for i in range(len(sudo_station_list)):
    total += len(merge_df[merge_df['station_code']==sudo_station_list[i]])
    print(sudo_station_list[i], len(merge_df[merge_df['station_code']==sudo_station_list[i]]))
    merge_df[merge_df['station_code']==sudo_station_list[i]].sort_values(by='obs_date')
    
print(len(sudo_station_list), len(merge_df), total)
# Out:
# 10064030 96363
# 10074010 96363
# 10074020 96363
# 10074030 96363
# 10074040 96363
# 10074060 96363
# 10074070 96363
# 10074080 96363
# 10074090 96363
# 10074100 96363
# 10074110 96363
# 10074120 96363
# 10074170 96363
# 10074175 96363
# 10134020 96363
# 10134030 96363
# 10134045 96363
# 10134140 96363
# 10154010 96363
# 10154020 96363
# 10154030 96363
# 10154032 96363
# 10154035 96363
# 10164010 96363
# 10164020 96363
# 10164030 96363
# 10164040 96363
# 10164050 96363
# 10164060 96363
# 10164070 96363
# 10164075 96363
# 10164080 96363
# 10174020 96363
# 10184010 96363
# 10184020 96363
# 10184030 96363
# 10184040 96363
# 10184050 96363
# 10184060 96363
# 10184070 96363
# 10184080 96363
# 10184090 96363
# 10184100 96363
# 10184110 96363
# 10184120 96363
# 10184125 96363
# 10184130 96363
# 10184140 96363
# 10184150 96363
# 10184160 96363
# 10184170 96363
# 10184180 96363
# 10184190 96363
# 10184200 96363
# 10184210 96363
# 10184220 96363
# 10184230 96363
# 10184232 96363
# 10194010 96363
# 10194020 96363
# 10194030 96363
# 10204010 96363
# 10204020 96363
# 10214010 96363
# 10214020 96363
# 10214030 96363
# 10224010 96363
# 10224020 96363
# 10224040 96363
# 10224050 96363
# 10224060 96363
# 10224070 96363
# 10224090 96363
# 10234010 96363
# 10234020 96363
# 10234030 96363
# 10234040 96363
# 11014010 96363
# 11014020 96363
# 11014030 96363
# 11014040 96363
# 11014060 96363
# 11014070 96363
# 11014080 96363
# 11014090 96363
# 11014100 96363
# 11014120 96363
# 11014130 96363
# 11014140 96363
# 12014010 96363
# 12024010 96363
# 12024020 96363
# 92 8865396 8865396

# %%
## 수도권 지역 리스트
address_list = pd.unique(df_station['address']).tolist()
address_list, len(address_list)
# Out:
# (['경기도 양평군',
#   '경기도 이천군 장호원읍',
#   '경기도 여주시',
#   '경기도 이천시',
#   '경기도 안성시',
#   '경기도 광주시',
#   '경기도 여주군',
#   '경기도 가평군',
#   '경기도 용인시',
#   '경기도 광주시 ',
#   '경기도 남양주시',
#   '경기도 의정부시',
#   '경기도 포천시',
#   '경기도 군포시 군포2동',
#   '경기도 성남시',
#   '경기도 남양주시 조안면',
#   '서울특별시 서대문구',
#   '서울특별시 구로구',
#   '경기도 안양시',
#   '서울특별시',
#   '서울특별시 성동구',
#   '경기도 과천시',
#   '경기도 부천시',
#   '경기도 군포시',
#   '서울특별시 노원구',
#   '경기도 의왕시',
#   '경기도 김포시',
#   '인천광역시 계양구 귤현동',
#   '서울특별시 강서구 개화동',
#   '경기도 연천군',
#   '경기도 연천군 중면',
#   '경기도 연천군 군남면',
#   '경기도 양주시',
#   '경기도 파주시',
#   '경기도 평택시',
#   '경기도 화성시',
#   '인천광역시 서구 오류동',
#   '경기도 안산시'],
#  38)

# %%
## 지역별 관측소 리스트
stations_by_address_list = []
total = 0
for i in range(len(address_list)):
    total += len(merge_df[merge_df['address']==address_list[i]])
    stations = pd.unique(merge_df[merge_df['address']==address_list[i]]['station_code']).tolist()
    stations_by_address_list.append(stations)
    print(pd.unique(merge_df[merge_df['address']==address_list[i]]['station_code']).tolist())
    print(address_list[i], len(merge_df[merge_df['address']==address_list[i]]))
    
print(total)
stations_by_address_list
# Out:
# [10064030, 10074010, 10074040, 10074170]
# 경기도 양평군 385452
# [10074020]
# 경기도 이천군 장호원읍 96363
# [10074030, 10074070, 10074100, 10074120]
# 경기도 여주시 385452
# [10074060, 10074090]
# 경기도 이천시 192726
# [10074080, 11014020, 11014120, 11014130]
# 경기도 안성시 385452
# [10074110, 10164010, 10164020, 10164080]
# 경기도 광주시 385452
# [10074175]
# 경기도 여주군 96363
# [10134020, 10134030, 10134045, 10134140, 10154010, 10154020, 10154030, 10154032, 10154035]
# 경기도 가평군 867267
# [10164030, 10164040, 10164050, 10164060, 10164070, 11014030, 11014090, 11014100]
# 경기도 용인시 770904
# [10164075]
# 경기도 광주시  96363
# [10174020, 10184060, 10184110, 10184220, 10184232]
# 경기도 남양주시 481815
# [10184010, 10184125]
# 경기도 의정부시 192726
# [10184020, 10184120, 10224010, 10224020, 10224040, 10224060, 10224070, 10224090]
# 경기도 포천시 770904
# [10184030]
# 경기도 군포시 군포2동 96363
# [10184040, 10184130, 10184180, 10184230]
# 경기도 성남시 385452
# [10184050]
# 경기도 남양주시 조안면 96363
# [10184070]
# 서울특별시 서대문구 96363
# [10184080]
# 서울특별시 구로구 96363
# [10184090]
# 경기도 안양시 96363
# [10184100]
# 서울특별시 96363
# [10184140]
# 서울특별시 성동구 96363
# [10184150]
# 경기도 과천시 96363
# [10184160]
# 경기도 부천시 96363
# [10184170]
# 경기도 군포시 96363
# [10184190, 10184200]
# 서울특별시 노원구 192726
# [10184210]
# 경기도 의왕시 96363
# [10194010]
# 경기도 김포시 96363
# [10194020]
# 인천광역시 계양구 귤현동 96363
# [10194030]
# 서울특별시 강서구 개화동 96363
# [10204010, 10204020, 10214010]
# 경기도 연천군 289089
# [10214020]
# 경기도 연천군 중면 96363
# [10214030]
# 경기도 연천군 군남면 96363
# [10224050]
# 경기도 양주시 96363
# [10234010, 10234020, 10234030, 10234040, 11014140]
# 경기도 파주시 481815
# [11014010, 11014070, 11014080]
# 경기도 평택시 289089
# [11014040, 11014060]
# 경기도 화성시 192726
# [12014010]
# 인천광역시 서구 오류동 96363
# [12024010, 12024020]
# 경기도 안산시 192726
# 8865396
# [[10064030, 10074010, 10074040, 10074170],
#  [10074020],
#  [10074030, 10074070, 10074100, 10074120],
#  [10074060, 10074090],
#  [10074080, 11014020, 11014120, 11014130],
#  [10074110, 10164010, 10164020, 10164080],
#  [10074175],
#  [10134020,
#   10134030,
#   10134045,
#   10134140,
#   10154010,
#   10154020,
#   10154030,
#   10154032,
#   10154035],
#  [10164030,
#   10164040,
#   10164050,
#   10164060,
#   10164070,
#   11014030,
#   11014090,
#   11014100],
#  [10164075],
#  [10174020, 10184060, 10184110, 10184220, 10184232],
#  [10184010, 10184125],
#  [10184020,
#   10184120,
#   10224010,
#   10224020,
#   10224040,
#   10224060,
#   10224070,
#   10224090],
#  [10184030],
#  [10184040, 10184130, 10184180, 10184230],
#  [10184050],
#  [10184070],
#  [10184080],
#  [10184090],
#  [10184100],
#  [10184140],
#  [10184150],
#  [10184160],
#  [10184170],
#  [10184190, 10184200],
#  [10184210],
#  [10194010],
#  [10194020],
#  [10194030],
#  [10204010, 10204020, 10214010],
#  [10214020],
#  [10214030],
#  [10224050],
#  [10234010, 10234020, 10234030, 10234040, 11014140],
#  [11014010, 11014070, 11014080],
#  [11014040, 11014060],
#  [12014010],
#  [12024010, 12024020]]

# %%
len(stations_by_address_list)
# Out:
# 38

# %% [markdown]
# # 지역별 관측소마다의 강수량

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
plt.rc('font', family='Malgun Gothic')
mpl.rcParams['axes.unicode_minus'] = False

# %%
for i in range(len(stations_by_address_list)):
    plt.figure(figsize=(18,10))
    for j in range(len(stations_by_address_list[i])):
        plt.xlabel('년도')
        plt.ylabel('강수량')
        plt.title(address_list[i] + ', 관측소 갯수: ' + str(len(stations_by_address_list[i])))
        plt.plot(merge_df[merge_df['station_code']==stations_by_address_list[i][j]]['obs_date'], merge_df[merge_df['station_code']==stations_by_address_list[i][j]]['rainfall'], label=str(stations_by_address_list[i][j]))
    plt.show()

# %% [markdown]
# ## 관측소별 강수량
# - 강수량이 음수인 값, 강수량(2010-2020)이 모두 0인 값, 결측값 해결해야함
